# %% [markdown]
# # STEP-1 BUSINESS PROBLEM UNDERSTANDING

# %% [markdown]
# ## Predicting the admission in an university by considering various inputs

# %% [markdown]
# # STEP-2 DATA UNDERSTANDING

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter("ignore")

# %%
df=pd.read_csv("admission_predict (1).csv")
df
# Out:
#      SNO  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0      1        337          118                  4  4.5   4.5  9.65
# 1      2        324          107                  4  4.0   4.5  8.87
# 2      3        316          104                  3  3.0   3.5  8.00
# 3      4        322          110                  3  3.5   2.5  8.67
# 4      5        314          103                  2  2.0   3.0  8.21
# ..   ...        ...          ...                ...  ...   ...   ...
# 495  496        332          108                  5  4.5   4.0  9.02
# 496  497        337          117                  5  5.0   5.0  9.87
# 497  498        330          120                  5  4.5   5.0  9.56
# 498  499        312          103                  4  4.0   5.0  8.43
# 499  500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.76
# 2           1              0.72
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SNO                500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
df["SNO"]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 495    496
# 496    497
# 497    498
# 498    499
# 499    500
# Name: SNO, Length: 500, dtype: int64

# %%
df["GRE Score"]
# Out:
# 0      337
# 1      324
# 2      316
# 3      322
# 4      314
#       ...
# 495    332
# 496    337
# 497    330
# 498    312
# 499    327
# Name: GRE Score, Length: 500, dtype: int64

# %%
df["GRE Score"].unique()
# Out:
# array([337, 324, 316, 322, 314, 330, 321, 308, 302, 323, 325, 327, 328,
#        307, 311, 317, 319, 318, 303, 312, 334, 336, 340, 298, 295, 310,
#        300, 338, 331, 320, 299, 304, 313, 332, 326, 329, 339, 309, 315,
#        301, 296, 294, 306, 305, 290, 335, 333, 297, 293], dtype=int64)

# %%
df["GRE Score"].value_counts()
# Out:
# GRE Score
# 312    24
# 324    23
# 316    18
# 321    17
# 322    17
# 327    17
# 311    16
# 320    16
# 314    16
# 317    15
# 325    15
# 315    13
# 308    13
# 323    13
# 326    12
# 319    12
# 313    12
# 304    12
# 300    12
# 318    12
# 305    11
# 301    11
# 310    11
# 307    10
# 329    10
# 299    10
# 298    10
# 331     9
# 340     9
# 328     9
# 309     9
# 334     8
# 332     8
# 330     8
# 306     7
# 302     7
# 297     6
# 296     5
# 295     5
# 336     5
# 303     5
# 338     4
# 335     4
# 333     4
# 339     3
# 337     2
# 290     2
# 294     2
# 293     1
# Name: count, dtype: int64

# %%
df["TOEFL Score"]
# Out:
# 0      118
# 1      107
# 2      104
# 3      110
# 4      103
#       ...
# 495    108
# 496    117
# 497    120
# 498    103
# 499    113
# Name: TOEFL Score, Length: 500, dtype: int64

# %%
df["TOEFL Score"].unique()
# Out:
# array([118, 107, 104, 110, 103, 115, 109, 101, 102, 108, 106, 111, 112,
#        105, 114, 116, 119, 120,  98,  93,  99,  97, 117, 113, 100,  95,
#         96,  94,  92], dtype=int64)

# %%
df["TOEFL Score"].value_counts()
# Out:
# TOEFL Score
# 110    44
# 105    37
# 104    29
# 107    28
# 106    28
# 112    28
# 103    25
# 100    24
# 102    24
# 99     23
# 101    20
# 111    20
# 108    19
# 113    19
# 109    19
# 114    18
# 116    16
# 115    11
# 118    10
# 98     10
# 119    10
# 120     9
# 117     8
# 97      7
# 96      6
# 95      3
# 93      2
# 94      2
# 92      1
# Name: count, dtype: int64

# %%
df["University Rating"]
# Out:
# 0      4
# 1      4
# 2      3
# 3      3
# 4      2
#       ..
# 495    5
# 496    5
# 497    5
# 498    4
# 499    4
# Name: University Rating, Length: 500, dtype: int64

# %%
df["University Rating"].unique()
# Out:
# array([4, 3, 2, 5, 1], dtype=int64)

# %%
df["University Rating"].value_counts()
# Out:
# University Rating
# 3    162
# 2    126
# 4    105
# 5     73
# 1     34
# Name: count, dtype: int64

# %%
df["LOR "].unique()
# Out:
# array([4.5, 3.5, 2.5, 3. , 4. , 1.5, 2. , 5. , 1. ])

# %%
df["LOR "].value_counts()
# Out:
# LOR
# 3.0    99
# 4.0    94
# 3.5    86
# 4.5    63
# 2.5    50
# 5.0    50
# 2.0    46
# 1.5    11
# 1.0     1
# Name: count, dtype: int64

# %%
df["SOP"]
# Out:
# 0      4.5
# 1      4.0
# 2      3.0
# 3      3.5
# 4      2.0
#       ...
# 495    4.5
# 496    5.0
# 497    4.5
# 498    4.0
# 499    4.5
# Name: SOP, Length: 500, dtype: float64

# %%
df["SOP"].unique()
# Out:
# array([4.5, 4. , 3. , 3.5, 2. , 5. , 1.5, 1. , 2.5])

# %%
df["SOP"].value_counts()
# Out:
# SOP
# 4.0    89
# 3.5    88
# 3.0    80
# 2.5    64
# 4.5    63
# 2.0    43
# 5.0    42
# 1.5    25
# 1.0     6
# Name: count, dtype: int64

# %%
df["CGPA"].unique()
# Out:
# array([9.65, 8.87, 8.  , 8.67, 8.21, 9.34, 8.2 , 7.9 , 8.6 , 8.4 , 9.  ,
#        9.1 , 8.3 , 8.7 , 8.8 , 8.5 , 9.5 , 9.7 , 9.8 , 9.6 , 7.5 , 7.2 ,
#        7.3 , 8.1 , 9.4 , 9.2 , 7.8 , 7.7 , 9.3 , 8.85, 7.4 , 7.6 , 6.8 ,
#        8.92, 9.02, 8.64, 9.22, 9.16, 9.64, 9.76, 9.45, 9.04, 8.9 , 8.56,
#        8.72, 8.22, 7.54, 7.36, 8.02, 9.36, 8.66, 8.42, 8.28, 8.14, 8.76,
#        7.92, 7.66, 8.03, 7.88, 7.84, 8.96, 9.24, 8.88, 8.46, 8.12, 8.25,
#        8.47, 9.05, 8.78, 9.18, 9.46, 9.38, 8.48, 8.68, 8.34, 8.45, 8.62,
#        7.46, 7.28, 8.84, 9.56, 9.48, 8.36, 9.32, 8.71, 9.35, 8.65, 9.28,
#        8.77, 8.16, 9.08, 9.12, 9.15, 9.44, 9.92, 9.11, 8.26, 9.43, 9.06,
#        8.75, 8.89, 8.69, 7.86, 9.01, 8.97, 8.33, 8.27, 7.98, 8.04, 9.07,
#        9.13, 9.23, 8.32, 8.98, 8.94, 9.53, 8.52, 8.43, 8.54, 9.91, 9.87,
#        7.65, 7.89, 9.14, 9.66, 9.78, 9.42, 9.26, 8.79, 8.23, 8.53, 8.07,
#        9.31, 9.17, 9.19, 8.37, 7.68, 8.15, 8.73, 8.83, 8.57, 9.68, 8.09,
# ...

# %%
df["CGPA"].value_counts()
# Out:
# CGPA
# 8.76    9
# 8.00    9
# 8.12    7
# 8.45    7
# 8.54    7
#        ..
# 9.92    1
# 9.35    1
# 8.71    1
# 9.32    1
# 7.69    1
# Name: count, Length: 184, dtype: int64

# %%
df["Research"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df["Research"].value_counts()
# Out:
# Research
# 1    280
# 0    220
# Name: count, dtype: int64

# %%
df["Chance of Admit "].unique()
# Out:
# array([0.92, 0.76, 0.72, 0.8 , 0.65, 0.9 , 0.75, 0.68, 0.5 , 0.45, 0.52,
#        0.84, 0.78, 0.62, 0.61, 0.54, 0.66, 0.63, 0.64, 0.7 , 0.94, 0.95,
#        0.97, 0.44, 0.46, 0.74, 0.91, 0.88, 0.58, 0.48, 0.49, 0.53, 0.87,
#        0.86, 0.89, 0.82, 0.56, 0.36, 0.42, 0.47, 0.55, 0.57, 0.96, 0.93,
#        0.38, 0.34, 0.79, 0.71, 0.69, 0.59, 0.85, 0.77, 0.81, 0.83, 0.67,
#        0.73, 0.6 , 0.43, 0.51, 0.39, 0.37])

# %%
df["Chance of Admit "].value_counts()
# Out:
# Chance of Admit
# 0.71    23
# 0.64    19
# 0.73    18
# 0.72    16
# 0.79    16
#         ..
# 0.38     2
# 0.36     2
# 0.43     1
# 0.39     1
# 0.37     1
# Name: count, Length: 61, dtype: int64

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ### For Continuous Variables

# %%
continuous_features=["SOP","CGPA","LOR ","Chance of Admit ","GRE Score","University Rating","TOEFL Score","Research"]

# %%
df[continuous_features].describe()
# Out:
#               SOP        CGPA       LOR   Chance of Admit    GRE Score  \
# count  500.000000  500.000000  500.00000         500.00000  500.000000
# mean     3.374000    8.576440    3.48400           0.72174  316.472000
# std      0.991004    0.604813    0.92545           0.14114   11.295148
# min      1.000000    6.800000    1.00000           0.34000  290.000000
# 25%      2.500000    8.127500    3.00000           0.63000  308.000000
# 50%      3.500000    8.560000    3.50000           0.72000  317.000000
# 75%      4.000000    9.040000    4.00000           0.82000  325.000000
# max      5.000000    9.920000    5.00000           0.97000  340.000000
#
#        University Rating  TOEFL Score    Research
# count         500.000000   500.000000  500.000000
# mean            3.114000   107.192000    0.560000
# std             1.143512     6.081868    0.496884
# min             1.000000    92.000000    0.000000
# 25%             2.000000   103.000000    0.000000
# ...

# %%
plt.rcParams["figure.figsize"] = (18,8)
plt.subplot(1,9, 1)
sns.histplot(df["SOP"],kde=True)
plt.subplot(1,9, 2)
sns.histplot(df["CGPA"],kde=True)
plt.subplot(1,9, 3)
sns.histplot(df["LOR "],kde=True)
plt.subplot(1,9, 4)
sns.histplot(df["Chance of Admit "],kde=True)
plt.subplot(1,9, 5)
sns.histplot(df["GRE Score"],kde=True)
plt.subplot(1,9,6 )
sns.histplot(df["University Rating"],kde=True)
plt.subplot(1,9, 7)
sns.histplot(df["TOEFL Score"],kde=True)
plt.subplot(1,9, 8)
sns.histplot(df["Research"],kde=True)

plt.suptitle("Univariate Analysis on Numerical Columns")
plt.show()

# %%
sns.pairplot(df[continuous_features])
plt.show()

# %%
df.corr()
# Out:
#                         SNO  GRE Score  TOEFL Score  University Rating  \
# SNO                1.000000  -0.103839    -0.141696          -0.067641
# GRE Score         -0.103839   1.000000     0.827200           0.635376
# TOEFL Score       -0.141696   0.827200     1.000000           0.649799
# University Rating -0.067641   0.635376     0.649799           1.000000
# SOP               -0.137352   0.613498     0.644410           0.728024
# LOR               -0.003694   0.524679     0.541563           0.608651
# CGPA              -0.074289   0.825878     0.810574           0.705254
# Research          -0.005332   0.563398     0.467012           0.427047
# Chance of Admit    0.008505   0.810351     0.792228           0.690132
#
#                         SOP      LOR       CGPA  Research  Chance of Admit
# SNO               -0.137352 -0.003694 -0.074289 -0.005332          0.008505
# GRE Score          0.613498  0.524679  0.825878  0.563398          0.810351
# ...

# %%
sns.heatmap(df[continuous_features].corr(),annot=True)
plt.show()

# %% [markdown]
# ## Steps to be followed for data cleaning

# %% [markdown]
# ### Check for Wrong Data

# %% [markdown]
# ### Check for Wrong Data Format

# %% [markdown]
# ### Check for Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Check for Missing Values

# %%
df.isnull().sum()
# Out:
# SNO                  0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# SNO                  0.0
# GRE Score            0.0
# TOEFL Score          0.0
# University Rating    0.0
# SOP                  0.0
# LOR                  0.0
# CGPA                 0.0
# Research             0.0
# Chance of Admit      0.0
# dtype: float64

# %% [markdown]
# ### Check for Skewness

# %%
df[continuous_features].skew()
# Out:
# SOP                 -0.228972
# CGPA                -0.026613
# LOR                 -0.145290
# Chance of Admit     -0.289966
# GRE Score           -0.039842
# University Rating    0.090295
# TOEFL Score          0.095601
# Research            -0.242475
# dtype: float64

# %% [markdown]
# ### Check for Outliers

# %%
plt.subplot(1,9, 1)
sns.boxplot(df["SOP"])
plt.subplot(1,9, 2)
sns.boxplot(df["CGPA"])
plt.subplot(1,9, 3)
sns.boxplot(df["LOR "])
plt.subplot(1,9, 4)
sns.boxplot(df["Chance of Admit "])
plt.subplot(1,9, 5)
sns.boxplot(df["GRE Score"])
plt.subplot(1,9, 6)
sns.boxplot(df["University Rating"])
plt.subplot(1,9, 7)
sns.boxplot(df["TOEFL Score"])
plt.subplot(1,9, 8)
sns.boxplot(df["Research"])
plt.suptitle("Outliers in the data")
plt.show()

# %% [markdown]
# # STEP-3 DATAPREPROCESSING

# %% [markdown]
# ## I.Data Cleaning

# %% [markdown]
# ### No Treatment for wrong data(Because there are no wrong data values in this dataset

# %% [markdown]
# ### No Treatment for wrong datatype(Because there are no wrong data type values in this dataset

# %% [markdown]
# ### No Treatment for Duplicates(Because there are no duplicate values in this dataset

# %% [markdown]
# ### No Treatment for missing values(Because there are no missing values in this dataset)

# %% [markdown]
# ### No Treatment for outliers(Because there are no outliers in this dataset)

# %% [markdown]
# ## II.Data Wrangling

# %% [markdown]
# ### No Treatment for Feature Encoding(Because all the valuues are in numerical format)

# %% [markdown]
# ### No Treatment for Feature Transformations(Because all the values are in normalized format)

# %% [markdown]
# ### No Treatment for Feature Scaling(Because all the vales are in normalied format)

# %%
df.shape
# Out:
# (500, 9)

# %%
df.drop("SNO",axis=1,inplace=True)
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# ...

# %% [markdown]
# ## X&y

# %%
X=df[["SOP","CGPA","LOR ","GRE Score","University Rating","TOEFL Score","Research"]]
y=df["Chance of Admit "]

# %%
X
# Out:
#      SOP  CGPA  LOR   GRE Score  University Rating  TOEFL Score  Research
# 0    4.5  9.65   4.5        337                  4          118         1
# 1    4.0  8.87   4.5        324                  4          107         1
# 2    3.0  8.00   3.5        316                  3          104         1
# 3    3.5  8.67   2.5        322                  3          110         1
# 4    2.0  8.21   3.0        314                  2          103         0
# ..   ...   ...   ...        ...                ...          ...       ...
# 495  4.5  9.02   4.0        332                  5          108         1
# 496  5.0  9.87   5.0        337                  5          117         1
# 497  4.5  9.56   5.0        330                  5          120         1
# 498  4.0  8.43   5.0        312                  4          103         0
# 499  4.5  9.04   4.5        327                  4          113         0
#
# [500 rows x 7 columns]

# %% [markdown]
# ## Identify the best random number

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression  # or RandomForestRegressor
from sklearn.metrics import r2_score
import pandas as pd
Train = []
Test = []
CV = []
for i in range(0, 101):
    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=i)

    # Regression model (you can swap with RandomForestRegressor or SVR)
    model = LinearRegression()
    model.fit(X_train, y_train)

    # Predictions
    ypred_train = model.predict(X_train)
    ypred_test = model.predict(X_test)

    # R² scores
    Train.append(r2_score(y_train, ypred_train))
    Test.append(r2_score(y_test, ypred_test))

    # Cross-validation R²
    CV.append(cross_val_score(model, X_train, y_train, cv=5, scoring="r2").mean())

# Create dataframe
em = pd.DataFrame({"Train": Train, "Test": Test, "CV": CV})

# Filter for stable scores
gm = em[(abs(em["Train"] - em["Test"]) <= 0.05) & (abs(em["Test"] - em["CV"]) <= 0.05)]

# Get the best random_state
rs = gm[gm["CV"] == gm["CV"].max()].index.to_list()[0]
print("Best random_state number:", rs)
# Out:
# Best random_state number: 8

# %% [markdown]
# ## III.train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=8)

# %% [markdown]
# # STEP-4.ML MODELLING

# %% [markdown]
# ### 1.Linear Regression Algorithm

# %%
from sklearn.linear_model import LinearRegression

# Modelling
linear_model=LinearRegression()
linear_model.fit(X_train,y_train)

# Evaluation
train_predictions=linear_model.predict(X_train)
test_predictions=linear_model.predict(X_test)

print("Train R2:",linear_model.score(X_train,y_train))
print("Test R2:",linear_model.score(X_test,y_test))
from sklearn.model_selection import cross_val_score
print("Cross Validation Score:",cross_val_score(model,X,y,cv=5).mean())
# Out:
# Train R2: 0.829359025100307
# Test R2: 0.7858508184037282
# Cross Validation Score: 0.8108015220863886

# %% [markdown]
# ### 2.Lasso Regression Algorithm

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
# Step 1: Hyperparameter Tuning using GridSearchCV
estimator = Lasso()
param_grid = {"alpha": list(range(1, 100))}  # Trying alpha values from 1 to 99
model_hp = GridSearchCV(estimator, param_grid, cv=5, scoring="r2")

# Fit the model using GridSearchCV to find the best alpha
model_hp.fit(X_train, y_train)

# Get the best alpha
print("Best Alpha from GridSearchCV:", model_hp.best_params_)
# Out:
# Best Alpha from GridSearchCV: {'alpha': 1}

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

# Step 2: Train Lasso using the best alpha found
lasso_best = Lasso(alpha=model_hp.best_params_['alpha'])
lasso_best.fit(X_train, y_train)

# Step 3: Print Intercept and Coefficients
print("Intercept:", lasso_best.intercept_)
print("Coefficients:", lasso_best.coef_)

# Step 4: Predictions and Evaluations
ypred_train = lasso_best.predict(X_train)
print("Train R2:", r2_score(y_train, ypred_train))

print("CV Score:", cross_val_score(lasso_best, X_train, y_train, cv=5).mean())

ypred_test = lasso_best.predict(X_test)
print("Test R2:", r2_score(y_test, ypred_test))
# Out:
# Intercept: -0.05273551898983242
# Coefficients: [0.         0.         0.         0.00244577 0.         0.
#  0.        ]
# Train R2: 0.2787258058654749
# CV Score: 0.2718617305946815
# Test R2: 0.2796429766888512

# %% [markdown]
# ### 3.Ridge Regression Algorithm

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge

# Step 1: Hyperparameter Tuning using GridSearchCV
estimator=Ridge()
param_grid={"alpha":list(range(1,100))}
model_hp=GridSearchCV(estimator,param_grid,cv=5,scoring="r2")

# Fit the model using GridSearchCV to find the best alpha
model_hp.fit(X_train,y_train)

# Get the best alpha
print("Best Alpha from GridSearchCV:", model_hp.best_params_)
# Out:
# Best Alpha from GridSearchCV: {'alpha': 1}

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

# Step 2: Train Ridge using the best alpha found
ridge_best = Ridge(alpha=model_hp.best_params_['alpha'])
ridge_best.fit(X_train, y_train)

# Step 3: Print Intercept and Coefficients
print("Intercept:", ridge_best.intercept_)
print("Coefficients:", ridge_best.coef_)

# Step 4: Predictions and Evaluations
ypred_train = ridge_best.predict(X_train)
print("Train R2:", r2_score(y_train, ypred_train))

print("CV Score:", cross_val_score(ridge_best, X_train, y_train, cv=5).mean())

ypred_test = ridge_best.predict(X_test)
print("Test R2:", r2_score(y_test, ypred_test))
# Out:
# Intercept: -1.352587343428236
# Coefficients: [-0.00183114  0.11628357  0.01676839  0.00200052  0.00608039  0.00333828
#   0.02498186]
# Train R2: 0.8293053385938982
# CV Score: 0.8224263993668448
# Test R2: 0.7859973483286555

# %% [markdown]
# ### 4.Elastic Net Regression Algorithm

# %%
from sklearn.linear_model import ElasticNet

# Base ElasticNet model (default parameters)
enr_base = ElasticNet()
enr_base.fit(X_train, y_train)

# Predict on training and test sets
train_predictions = enr_base.predict(X_train)
test_predictions = enr_base.predict(X_test)

# Model evaluation using R² score
print("Train R2:", enr_base.score(X_train, y_train))  # Measures training performance
print("Test R2:", enr_base.score(X_test, y_test))    # Measures generalization to test data

# Cross-validation for robust performance estimate
from sklearn.model_selection import cross_val_score
print("Cross Validation Score:", cross_val_score(enr_base, X, y, cv=5).mean())
# Out:
# Train R2: 0.5705650141894687
# Test R2: 0.5494487255502882
# Cross Validation Score: 0.5324389764785071

# %%
from sklearn.model_selection import GridSearchCV

# Grid search for hyperparameter tuning
estimator = ElasticNet()
param_grid = {
    "alpha": list(range(200, 300)),           # Regularization strength
    "l1_ratio": [0.1, 0.5, 0.75, 0.9, 0.95, 1] # Balance between L1 and L2
}
model_hp = GridSearchCV(estimator, param_grid, cv=5, scoring="neg_mean_squared_error")
model_hp.fit(X_train, y_train)

# Best parameters found by grid search
model_hp.best_params_
# Out:
# {'alpha': 200, 'l1_ratio': 0.1}

# %%
from sklearn.linear_model import ElasticNet

# Best model from grid search
enr_best = ElasticNet(alpha=200, l1_ratio=1)
enr_best.fit(X_train, y_train)

# Model parameters
print("Intercept:", enr_best.intercept_)
print("coefficients:", enr_best.coef_)

# Train prediction and R² score
ypred_train = enr_best.predict(X_train)
from sklearn.metrics import r2_score
print("Train R2:", r2_score(y_train, ypred_train))

# Cross-validation score
from sklearn.model_selection import cross_val_score
print("CV Score:", cross_val_score(enr_best, X_train, y_train, cv=5).mean())

# Test prediction and R² score
ypred_test = enr_best.predict(X_test)
print("Test R2:", r2_score(y_test, ypred_test))
# Out:
# Intercept: 0.721875
# coefficients: [0. 0. 0. 0. 0. 0. 0.]
# Train R2: 0.0
# CV Score: -0.008590752578734762
# Test R2: -2.4812716745481467e-05

# %% [markdown]
# ### 5.Polynomial Regression Algorithm

# %%
from sklearn.preprocessing import PolynomialFeatures

# Generate polynomial features of degree 1 (which is just linear regression)
polynomial_converter = PolynomialFeatures(degree=1)
X_train_poly = pd.DataFrame(polynomial_converter.fit_transform(X_train))

from sklearn.linear_model import LinearRegression
# Train linear regression model
model = LinearRegression()
model.fit(X_train_poly, y_train)

# Predict and evaluate on training data
ypred_train = model.predict(X_train_poly)

# %%
from sklearn.metrics import mean_squared_error, r2_score
print("Train RMSE:", np.sqrt(mean_squared_error(y_train, ypred_train)))
print("Train R2:", r2_score(y_train, ypred_train))

from sklearn.model_selection import cross_val_score
print("Cross Validation Score:", cross_val_score(model, X_train_poly, y_train, cv=5).mean())

# Transform test data and evaluate model
X_test_poly = pd.DataFrame(polynomial_converter.fit_transform(X_test))
ypred_test = model.predict(X_test_poly)

print("Test RMSE:", np.sqrt(mean_squared_error(y_test, ypred_test)))
print("Test R2:", r2_score(y_test, ypred_test))
# Out:
# Train RMSE: 0.058798181480776014
# Train R2: 0.829359025100307
# Cross Validation Score: 0.8224787960345953
# Test RMSE: 0.06270827055510649
# Test R2: 0.7858508184037283

# %% [markdown]
# ### 6.Support Vector Regression Algorithm

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV, cross_val_score

# Define parameter grid
param_grid = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf'],
    'gamma': ['scale', 'auto']
}

# Base model
svr = SVR()

# Grid search
grid_search = GridSearchCV(svr, param_grid, cv=5, scoring='r2')
grid_search.fit(X_train, y_train)

# Best model from grid search
best_model = grid_search.best_estimator_

# Evaluation
print("Best Parameters:", grid_search.best_params_)
print("Train R2:", best_model.score(X_train, y_train))
print("Test R2:", best_model.score(X_test, y_test))

# Cross-validation score using best model
cv_score = cross_val_score(best_model, X, y, cv=5, scoring='r2')
print("Cross Validation R2 Score:", cv_score.mean())
# Out:
# Best Parameters: {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# Train R2: 0.8031571078110137
# Test R2: 0.7421853609852753
# Cross Validation R2 Score: 0.7823245655801798

# %% [markdown]
# ### 7.Random Forest Regression Algorithm

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, cross_val_score

# Define the parameter grid for tuning
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

# Initialize the model
rf = RandomForestRegressor(random_state=8)

# Grid search
grid_search = GridSearchCV(rf, param_grid, cv=5, scoring='r2')
grid_search.fit(X_train, y_train)

# Best model from grid search
best_model = grid_search.best_estimator_

# Evaluation
print("Best Parameters:", grid_search.best_params_)
print("Train R2:", best_model.score(X_train, y_train))
print("Test R2:", best_model.score(X_test, y_test))

# Cross-validation score
cv_score = cross_val_score(best_model, X, y, cv=5, scoring='r2')
print("Cross Validation R2 Score:", cv_score.mean())
# Out:
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# Train R2: 0.9370494401313249
# Test R2: 0.770449950117275
# Cross Validation R2 Score: 0.7840742896324446

# %% [markdown]
# # STEP-5 Save the Best model

# %%
from joblib import dump

dump(model,"admission_predict.joblib")
# Out:
# ['admission_predict.joblib']

# %% [markdown]
# # STEP-6 Predict on new data

# %% [markdown]
# ## Student-1:-

# %%
input_data={"SNO":65,
            "SOP":4.2,
            "CGPA":8.9,
            "LOR ":3.2,
            "GRE Score":200,
            "University Rating":3,
            "TOEFL Score":60,
            "Research":1}

# %%
df = pd.DataFrame(input_data,index=[0])
df
# Out:
#    SNO  SOP  CGPA  LOR   GRE Score  University Rating  TOEFL Score  Research
# 0   65  4.2   8.9   3.2        200                  3           60         1

# %% [markdown]
# ### Apply Data preprocessing on unknown data

# %%
df.drop("SNO",axis=1,inplace=True)

X_new = df

# %%
X_new
# Out:
#    SOP  CGPA  LOR   GRE Score  University Rating  TOEFL Score  Research
# 0  4.2   8.9   3.2        200                  3           60         1

# %%
X_new = X_new[["SOP","CGPA","LOR ","GRE Score","University Rating","TOEFL Score","Research"]]
linear_model.predict(X_new)
# Out:
# array([0.38805977])

# %% [markdown]
# ### The person has a 38.8% chance of getting a seat at the university.

# %% [markdown]
# ## Student-2:-

# %%
input_data={"SNO":67,
            "SOP":4.5,
            "CGPA":9.65,
            "LOR ":4.5,
            "GRE Score":337,
            "University Rating":4,
            "TOEFL Score":118,
            "Research":1}

# %%
df = pd.DataFrame(input_data,index=[0])
df
# Out:
#    SNO  SOP  CGPA  LOR   GRE Score  University Rating  TOEFL Score  Research
# 0   67  4.5  9.65   4.5        337                  4          118         1

# %% [markdown]
# ### Apply Data preprocessing on unknown data

# %%
df.drop("SNO",axis=1,inplace=True)

X_new = df

# %%
X_new
# Out:
#    SOP  CGPA  LOR   GRE Score  University Rating  TOEFL Score  Research
# 0  4.5  9.65   4.5        337                  4          118         1

# %%
X_new = X_new[["SOP","CGPA","LOR ","GRE Score","University Rating","TOEFL Score","Research"]]
linear_model.predict(X_new)
# Out:
# array([0.95463356])

# %% [markdown]
# ### The person has a 95.4% chance of getting a seat at the university.
